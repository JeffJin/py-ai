# %%
from collections import Counter

import time

import torch
import torch.nn as nn
from torch.nn import functional as F
from basic_tokenizer import BasicTokenizer

device = 'cuda' if torch.cuda.is_available() else 'cpu'
eng = "\n".join(line for line in open("data/eng.txt", encoding="utf-8").read().splitlines() if line.strip())
kr = "\n".join(line for line in open("data/kr.txt", encoding="utf-8").read().splitlines() if line.strip())
chn = "\n".join(line for line in open("data/chn.txt", encoding="utf-8").read().splitlines() if line.strip())
content = eng + kr + chn
eng[:100], kr[:100], chn[:100]
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 8
#       4
#       5 import torch
#       6 import torch.nn as nn
#       7 from torch.nn import functional as F
# ----> 8 from basic_tokenizer import BasicTokenizer
#       9
#      10 device = 'cuda' if torch.cuda.is_available() else 'cpu'
#      11 eng = "\n".join(line for line in open("data/eng.txt", encoding="utf-8").read().splitlines() if line.strip())
#
# ModuleNotFoundError: No module named 'basic_tokenizer'

# %%
basic_tokenizer = BasicTokenizer()
basic_tokenizer.train(content, vocab_size=512, verbose=True)
basic_tokenizer.merges
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 basic_tokenizer = BasicTokenizer()
#       2 basic_tokenizer.train(content, vocab_size=512, verbose=True)
#       3 basic_tokenizer.merges
#
# NameError: name 'BasicTokenizer' is not defined
