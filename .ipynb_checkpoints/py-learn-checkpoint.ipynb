# %%
matrix_c = np.array([[1, 2, 3],
                       [4, 5, 6]]) # 2x3 matrix
matrix_d = np.array([[7, 8],
                       [9, 10],
                       [11, 12]]) # 3x2 matrix

# result_dot = np.dot(matrix_c, matrix_d) # Resulting 2x2 matrix
result_dot = matrix_c @ matrix_d
result_dot
# Out:
# array([[ 58,  64],
#        [139, 154]])

# %%
import numpy as np

# Create a 2x2 matrix
matrix_a = np.array([[1, 2],
                     [3, 4]])

# Create a 3x3 matrix
matrix_b = np.array([[5, 6, 7],
                     [8, 9, 10],
                     [11, 12, 13]])
result_add = matrix_a + matrix_a
result_sub = matrix_a - matrix_a
result_mul = matrix_a * matrix_a
result_div = matrix_a / matrix_a

result_div
# Out:
# array([[1., 1.],
#        [1., 1.]])
